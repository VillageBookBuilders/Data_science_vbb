# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
import pandas as pd
import os

class google_apis:
    __webdev_cred = ''
    __mentor_cred = ''

    def __init__(self):
        scopes = [
            'https://www.googleapis.com/auth/calendar',
            'https://www.googleapis.com/auth/gmail.compose',
            'https://www.googleapis.com/auth/admin.directory.user',
            'https://www.googleapis.com/auth/admin.directory.group',
        ]
        SERVICE_ACCOUNT_FILE = os.path.join("", "service-acc.json")
        credentials = service_account.Credentials.from_service_account_file(
            'service-acc.json', scopes=scopes)
        self.__webdev_cred = credentials.with_subject(
            'webdevelopment@villagebookbuilders.org')
        self.__mentor_cred = credentials.with_subject(
            'mentor@villagebookbuilders.org')


    def calendar_data_arr(self):
        data_arr = [['Associated Calendar', 'Meet Link', 'Participants', 'Start Time', 'End Time', 'ID']]
        calendar_service = build('calendar', 'v3', credentials=self.__mentor_cred)
        ids = calendar_service.calendarList().list().execute()
        for calendar_list_entry in ids['items']:
            print(calendar_list_entry['summary'])
            list = calendar_service.events().list(calendarId=calendar_list_entry['id']).execute()
            flag = True
            for event in list['items']:
                if 'hangoutLink' in event and 'attendees' in event:
                    data_arr.append([calendar_list_entry['summary'],
                                    event['hangoutLink'], event['attendees'], event['start'], event['end'], event['id']])
        df = pd.DataFrame(data_arr)
        print(df)
        df.to_csv('CalendarMeets_15Apr21.csv')

api_obj = google_apis()
api_obj.calendar_data_arr()
# Out:
# Holidays in United States
# Technology Development Testing Calendar (please don't delete)
# Adeiso, Ghana MP
# Biwi, Malawi
# mentor@villagebookbuilders.org
# Charity Center, Zambia MP
# Maragoli, Kenya MP
# Mukono, Uganda MP
# Jolly Land, Uganda MP
# High Tech, Uganda MP
# Ahero, Kenya MP
# VIMA, Ghana MP
# Kadzakalowa, Malawi MP
#                                                       0  ...                                            5
# 0                                   Associated Calendar  ...                                           ID
# 1     Technology Development Testing Calendar (pleas...  ...                   uomb30c90g30e2qmelmsvvop8s
# 2     Technology Development Testing Calendar (pleas...  ...                   1rs7r3bi27fjlmpjgdcsjbgs38
# 3     Technology Development Testing Calendar (pleas...  ...                   tibqdbc322ivhg5vg9j54pbpi8
# 4     Technology Development Testing Calendar (pleas...  ...                   mufl5dcq0nt378dr3b69kd3tg4
# ...                                                 ...  ...                                          ...
# 2129                             Kadzakalowa, Malawi MP  ...                   7dgt07r7llnsgf0qir85b0kum8
# 2130                             Kadzakalowa, Malawi MP  ...                   dicdru3d0qjvud1jos4g449cgk
# 2131                             Kadzakalowa, Malawi MP  ...                   uu9s02d0qungh1732k8jf9gidk
# 2132                             Kadzakalowa, Malawi MP  ...  uu9s02d0qungh1732k8jf9gidk_20210417T130000Z
# 2133                             Kadzakalowa, Malawi MP  ...  uu9s02d0qungh1732k8jf9gidk_20210424T130000Z
#
# [2134 rows x 6 columns]
